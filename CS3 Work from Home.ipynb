# %%
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score

#import pandas_profiling

# %%
os.chdir('C:\\Users\\User\\R-Markdowns\dataset_diabetes\dataset_diabetes')
os.listdir(os.getcwd())
# Out:
# ['diabetic_data.csv', 'IDs_mapping.csv']

# %%
data = pd.read_csv("diabetic_data.csv")

# %%
#data.profile_report(style={'full_width':True})

# %%
data["Readmitted?"] = (data.readmitted =="<30").astype("int")

# %%
data.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)      ?
# 1        149190     55629189        Caucasian  Female  [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3        500364     82442376        Caucasian    Male  [30-40)      ?
# 4         16680     42519267        Caucasian    Male  [40-50)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital     ...     insulin glyburide-metformin  \
# 0                 1     ...          No                  No
# ...

# %%
data = data[~data.discharge_disposition_id.isin([11,13,14,19,20,21])]

# %%
#compute for percentage of readmission
data["Readmitted?"].mean()
#this is an imbalance classification problem
# Out:
# 0.11388824577474005

# %%
data = data.replace("?",np.nan)

# %%
data
# Out:
#         encounter_id  patient_nbr             race  gender       age weight  \
# 0            2278392      8222157        Caucasian  Female    [0-10)    NaN
# 1             149190     55629189        Caucasian  Female   [10-20)    NaN
# 2              64410     86047875  AfricanAmerican  Female   [20-30)    NaN
# 3             500364     82442376        Caucasian    Male   [30-40)    NaN
# 4              16680     42519267        Caucasian    Male   [40-50)    NaN
# 5              35754     82637451        Caucasian    Male   [50-60)    NaN
# 6              55842     84259809        Caucasian    Male   [60-70)    NaN
# 7              63768    114882984        Caucasian    Male   [70-80)    NaN
# 8              12522     48330783        Caucasian  Female   [80-90)    NaN
# 9              15738     63555939        Caucasian  Female  [90-100)    NaN
# 10             28236     89869032  AfricanAmerican  Female   [40-50)    NaN
# ...

# %%
data.isnull().sum()
# Out:
# encounter_id                    0
# patient_nbr                     0
# race                         2234
# gender                          0
# age                             0
# weight                      96218
# admission_type_id               0
# discharge_disposition_id        0
# admission_source_id             0
# time_in_hospital                0
# payer_code                  39398
# medical_specialty           48616
# num_lab_procedures              0
# num_procedures                  0
# num_medications                 0
# number_outpatient               0
# number_emergency                0
# number_inpatient                0
# diag_1                         20
# diag_2                        356
# diag_3                       1419
# number_diagnoses                0
# max_glu_serum                   0
# A1Cresult                       0
# metformin                       0
# repaglinide                     0
# nateglinide                     0
# ...

# %%
#create new category for unknown values in race, payer_code, and medical_speciality
data["race"] = data["race"].fillna("UNKNOWN")
data["payer_code"] = data["payer_code"].fillna("UNKNOWN")
data["medical_specialty"] = data["medical_specialty"].fillna("UNKNOWN")

# %%
data.isnull().sum()
# Out:
# encounter_id                    0
# patient_nbr                     0
# race                            0
# gender                          0
# age                             0
# weight                      96218
# admission_type_id               0
# discharge_disposition_id        0
# admission_source_id             0
# time_in_hospital                0
# payer_code                      0
# medical_specialty               0
# num_lab_procedures              0
# num_procedures                  0
# num_medications                 0
# number_outpatient               0
# number_emergency                0
# number_inpatient                0
# diag_1                         20
# diag_2                        356
# diag_3                       1419
# number_diagnoses                0
# max_glu_serum                   0
# A1Cresult                       0
# metformin                       0
# repaglinide                     0
# nateglinide                     0
# ...

# %%
#medical specialty has a lot of values, think of what to do with it
#can change those not in top 10 to others
top_med = np.array(data.medical_specialty.value_counts().sort_values(ascending=False).index)[:10]
data.medical_specialty[~data.medical_specialty.isin(top_med)] = "Others"
data.head()
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)    NaN
# 1        149190     55629189        Caucasian  Female  [10-20)    NaN
# 2         64410     86047875  AfricanAmerican  Female  [20-30)    NaN
# 3        500364     82442376        Caucasian    Male  [30-40)    NaN
# 4         16680     42519267        Caucasian    Male  [40-50)    NaN
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# ...

# %%
data.medical_specialty.value_counts()
# Out:
# UNKNOWN                       48616
# InternalMedicine              14237
# Others                         8199
# Emergency/Trauma               7419
# Family/GeneralPractice         7252
# Cardiology                     5279
# Surgery-General                3059
# Nephrology                     1539
# Orthopedics                    1392
# Orthopedics-Reconstructive     1230
# Radiologist                    1121
# Name: medical_specialty, dtype: int64

# %%
##one-hot encoding for variables admission_type_id, discharge_disposition_id, admission_source_id

category_var = ["admission_type_id", "discharge_disposition_id", "admission_source_id"]
data[category_var] = data[category_var].astype("str")

# %%
np.array(data.columns)[2:data.shape[1]-2]
# Out:
# array(['race', 'gender', 'age', 'weight', 'admission_type_id',
#        'discharge_disposition_id', 'admission_source_id',
#        'time_in_hospital', 'payer_code', 'medical_specialty',
#        'num_lab_procedures', 'num_procedures', 'num_medications',
#        'number_outpatient', 'number_emergency', 'number_inpatient',
#        'diag_1', 'diag_2', 'diag_3', 'number_diagnoses', 'max_glu_serum',
#        'A1Cresult', 'metformin', 'repaglinide', 'nateglinide',
#        'chlorpropamide', 'glimepiride', 'acetohexamide', 'glipizide',
#        'glyburide', 'tolbutamide', 'pioglitazone', 'rosiglitazone',
#        'acarbose', 'miglitol', 'troglitazone', 'tolazamide', 'examide',
#        'citoglipton', 'insulin', 'glyburide-metformin',
#        'glipizide-metformin', 'glimepiride-pioglitazone',
#        'metformin-rosiglitazone', 'metformin-pioglitazone', 'change',
#        'diabetesMed'], dtype=object)

# %%
data.shape[1]
# Out:
# 51

# %%
print(len(data), data.patient_nbr.nunique(), data.encounter_id.nunique())
# Out:
# 99343 69990 99343

# %%
cols_num = ['time_in_hospital','num_lab_procedures', 'num_procedures', 'num_medications',
       'number_outpatient', 'number_emergency', 'number_inpatient','number_diagnoses']
cols_cat = ['race', 'gender', 
       'max_glu_serum', 'A1Cresult',
       'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide',
       'glimepiride', 'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide',
       'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone',
       'tolazamide', 'insulin',
       'glyburide-metformin', 'glipizide-metformin',
       'glimepiride-pioglitazone', 'metformin-rosiglitazone',
       'metformin-pioglitazone', 'change', 'diabetesMed','payer_code']

cols_cat_num = ['admission_type_id', 'discharge_disposition_id', 'admission_source_id']

data[cols_cat_num] = data[cols_cat_num].astype('str')

# %%
data_new =  pd.get_dummies(data[cols_cat + cols_cat_num + ['medical_specialty']],drop_first = True)

# %%
data = pd.concat([data,data_new],axis=1)

# %%
data.age = data.age.replace({'[0-10)':5, 
          '[10-20)':15, 
          '[20-30)':25, 
          '[30-40)':35, 
          '[40-50)':45, 
          '[50-60)':55,
          '[60-70)':65, 
          '[70-80)':75, 
          '[80-90)':85, 
          '[90-100)':95})

# %%
#or maybe drop weight na lang
data['has_weight'] = data.weight.notnull().astype('int')

# %% [markdown]
# ## what to with repeating patient numbers??

# %%
## removing raw eright column
cols_all_cat = np.array(data.columns)
cols_all_cat = np.delete(cols_all_cat,5)

# %%
cols_extra = ['age','has_weight']
cols = cols_num + list(cols_all_cat) + cols_extra

# %% [markdown]
# ### Create filtered column dataset

# %%
final = data[cols + ['Readmitted?']]

# %%
final.gender.value_counts()
# Out:
# Female             53454
# Male               45886
# Unknown/Invalid        3
# Name: gender, dtype: int64

# %%
final = final[final.gender!="Unknown/Invalid"]

# %%
y = final["Readmitted?"]
x = final.drop(["Readmitted?","readmitted","weight",'encounter_id', 'patient_nbr'],axis=1)

# %%
x.columns
# Out:
# Index(['time_in_hospital', 'num_lab_procedures', 'num_procedures',
#        'num_medications', 'number_outpatient', 'number_emergency',
#        'number_inpatient', 'number_diagnoses', 'encounter_id', 'patient_nbr',
#        ...
#        'medical_specialty_Orthopedics',
#        'medical_specialty_Orthopedics-Reconstructive',
#        'medical_specialty_Others', 'medical_specialty_Radiologist',
#        'medical_specialty_Surgery-General', 'medical_specialty_UNKNOWN',
#        'has_weight', 'age', 'has_weight', 'Readmitted?'],
#       dtype='object', length=195)

# %%
x.head()
# Out:
#    time_in_hospital  num_lab_procedures  num_procedures  num_medications  \
# 0                 1                  41               0                1
# 1                 3                  59               0               18
# 2                 2                  11               5               13
# 3                 2                  44               1               16
# 4                 1                  51               0                8
#
#    number_outpatient  number_emergency  number_inpatient  number_diagnoses  \
# 0                  0                 0                 0                 1
# 1                  0                 0                 0                 9
# 2                  2                 0                 1                 6
# 3                  0                 0                 0                 7
# 4                  0                 0                 0                 5
#
#               race  gender     ...      medical_specialty_Nephrology  \
# ...

# %% [markdown]
# ## Logistic Regression

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=0)
logit = LogisticRegression(fit_intercept=True, penalty='l1')
logit.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-118-9597f65f6890> in <module>()
#       1 X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=0)
#       2 logit = LogisticRegression(fit_intercept=True, penalty='l1')
# ----> 3 logit.fit(X_train, y_train)
#
# C:\Users\User\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py in fit(self, X, y, sample_weight)
#    1171
#    1172         X, y = check_X_y(X, y, accept_sparse='csr', dtype=np.float64,
# -> 1173                          order="C")
#    1174         check_classification_targets(y)
#    1175         self.classes_ = np.unique(y)
#
# ...

# %%
logit_pred = logit.predict(X_test)
pd.crosstab(pd.Series(y_test, name = 'Actual'), pd.Series(logit_pred, name = 'Predict'), margins = True)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score
print("Accuracy is {0:.2f}".format(accuracy_score(y_test, logit_pred)))
print("Precision is {0:.2f}".format(precision_score(y_test, logit_pred)))
print("Recall is {0:.2f}".format(recall_score(y_test, logit_pred)))

# %% [markdown]
# Typically, it is better to balance the data in some way to give the positives more weight. There are 3 strategies that are typically utilized
# sub-sample the more dominant class:
# - use a random subset of the negatives
# - over-sample the imbalanced class: use the same positive samples multiple times
# - create synthetic positive data
